# %% [markdown]
# ## Exploratory Data Analysis on Bike Sharing Data

# %% [markdown]
# ### Imports of Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### Markdown Report
